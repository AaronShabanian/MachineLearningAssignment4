#   3950K .......... .......... .......... .......... .......... 80% 8.08M 0s
#   4000K .......... .......... .......... .......... .......... 82% 4.61M 0s
#   4050K .......... .......... .......... .......... .......... 83% 8.42M 0s
#   4100K .......... .......... .......... .......... .......... 84% 10.1M 0s
#   4150K .......... .......... .......... .......... .......... 85% 7.29M 0s
#   4200K .......... .......... .......... .......... .......... 86% 6.18M 0s
#   4250K .......... .......... .......... .......... .......... 87% 9.53M 0s
#   4300K .......... .......... .......... .......... .......... 88% 18.6M 0s
#   4350K .......... .......... .......... .......... .......... 89% 6.10M 0s
#   4400K .......... .......... .......... .......... .......... 90% 14.6M 0s
#   4450K .......... .......... .......... .......... .......... 91% 8.89M 0s
#   4500K .......... .......... .......... .......... .......... 92% 12.3M 0s
#   4550K .......... .......... .......... .......... .......... 93% 4.88M 0s
#   4600K .......... .......... .......... .......... .......... 94% 9.40M 0s
#   4650K .......... .......... .......... .......... .......... 95% 4.61M 0s
#   4700K .......... .......... .......... .......... .......... 96% 5.93M 0s
#   4750K .......... .......... .......... .......... .......... 97% 13.4M 0s
#   4800K .......... .......... .......... .......... .......... 98% 9.65M 0s
#   4850K .......... .......... .......... .......... .......... 99% 10.7M 0s
#   4900K .......... .......... .......... ........             100% 14.2M=0.8s
#
# 2022-03-31 17:39:31 (5.90 MB/s) - 'C:/Users/a2sha/Documents/MachineLearning/MachineLearningAssignment4/bbc-text.csv' saved [5057493/5057493]
#
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\a2sha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Set Hyper-Parameters

# %%
vocab_size = 5000 # make the top list of words (common words)
embedding_dim = 64
max_length = 200
trunc_type = 'post'
padding_type = 'post'
oov_tok = '<OOV>' # OOV = Out of Vocabulary
training_portion = .8

# %% [markdown]
# Populate the list of articles and labels from the data and also remove the stopwords.

# %%
articles = []
labels = []

with open("C:/Users/a2sha/Documents/MachineLearning/MachineLearningAssignment4/bbc-text.csv", 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)
    for row in reader:
        labels.append(row[0])
        article = row[1]
        for word in STOPWORDS:
            token = ' ' + word + ' '
            article = article.replace(token, ' ')
            article = article.replace(' ', ' ')
        articles.append(article)

# %% [markdown]
# Creating train and validation set

# %%
train_size = int(len(articles) * training_portion)

train_articles = articles[0: train_size]
train_labels = labels[0: train_size]

validation_articles = articles[train_size:]
validation_labels = labels[train_size:]

# %% [markdown]
# Tokenize and Sequenize

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(train_articles)
word_index = tokenizer.word_index
train_sequences = tokenizer.texts_to_sequences(train_articles)
train_padded = pad_sequences(train_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
validation_sequences = tokenizer.texts_to_sequences(validation_articles)
validation_padded = pad_sequences(validation_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %% [markdown]
# Setting up labels

# %%
label_tokenizer = Tokenizer()
label_tokenizer.fit_on_texts(labels)

training_label_seq = np.array(label_tokenizer.texts_to_sequences(train_labels))
validation_label_seq = np.array(label_tokenizer.texts_to_sequences(validation_labels))

# %% [markdown]
# Creating the model

# %%
model=Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(Dropout(.5))
model.add(Bidirectional(LSTM(embedding_dim)))
model.add(Dense(6, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 64)          320000
#
#  dropout (Dropout)           (None, None, 64)          0
#
#  bidirectional (Bidirectiona  (None, 128)              66048
#  l)
#
#  dense (Dense)               (None, 6)                 774
#
# =================================================================
# Total params: 386,822
# Trainable params: 386,822
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compile

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.001, decay=1e-6)
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=opt,
    metrics=['accuracy'],
)

# %%
num_epochs = 10
history = model.fit(train_padded, training_label_seq, epochs=num_epochs, 
                    validation_data=(validation_padded, validation_label_seq), verbose=2)
# Out:
# Epoch 1/10
# 56/56 - 26s - loss: 1.5919 - accuracy: 0.2899 - val_loss: 1.5724 - val_accuracy: 0.2697 - 26s/epoch - 457ms/step
# Epoch 2/10
# 56/56 - 12s - loss: 1.1817 - accuracy: 0.5511 - val_loss: 0.7590 - val_accuracy: 0.8404 - 12s/epoch - 221ms/step
# Epoch 3/10
# 56/56 - 13s - loss: 0.6072 - accuracy: 0.8236 - val_loss: 0.6074 - val_accuracy: 0.7978 - 13s/epoch - 225ms/step
# Epoch 4/10
# 56/56 - 12s - loss: 0.3499 - accuracy: 0.9292 - val_loss: 0.4261 - val_accuracy: 0.8854 - 12s/epoch - 217ms/step
# Epoch 5/10
# 56/56 - 13s - loss: 0.1963 - accuracy: 0.9483 - val_loss: 0.3662 - val_accuracy: 0.9011 - 13s/epoch - 225ms/step
# Epoch 6/10
# 56/56 - 13s - loss: 0.1453 - accuracy: 0.9764 - val_loss: 0.2600 - val_accuracy: 0.9281 - 13s/epoch - 226ms/step
# Epoch 7/10
# 56/56 - 12s - loss: 0.0547 - accuracy: 0.9955 - val_loss: 0.1976 - val_accuracy: 0.9461 - 12s/epoch - 211ms/step
# Epoch 8/10
# 56/56 - 11s - loss: 0.0208 - accuracy: 0.9978 - val_loss: 0.2015 - val_accuracy: 0.9416 - 11s/epoch - 197ms/step
# Epoch 9/10
# 56/56 - 11s - loss: 0.0184 - accuracy: 0.9989 - val_loss: 0.1424 - val_accuracy: 0.9551 - 11s/epoch - 199ms/step
# Epoch 10/10
# 56/56 - 12s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.1723 - val_accuracy: 0.9483 - 12s/epoch - 223ms/step

# %% [markdown]
# Prediction Examples

# %%
txt = ["blair prepares to name poll date tony blair is likely to name 5 may as election day when parliament returns from its easter break  the bbc s political editor has learned.  andrew marr says mr blair will ask the queen on 4 or 5 april to dissolve parliament at the end of that week. mr blair has so far resisted calls for him to name the day but all parties have stepped up campaigning recently. downing street would not be drawn on the claim  saying election timing was a matter for the prime minister.  a number 10 spokeswoman would only say:  he will announce an election when he wants to announce an election.  the move will signal a frantic week at westminster as the government is likely to try to get key legislation through parliament. the government needs its finance bill  covering the budget plans  to be passed before the commons closes for business at the end of the session on 7 april.  but it will also seek to push through its serious and organised crime bill and id cards bill. mr marr said on wednesday s today programme:  there s almost nobody at a senior level inside the government or in parliament itself who doesn t expect the election to be called on 4 or 5 april.  as soon as the commons is back after the short easter recess  tony blair whips up to the palace  asks the queen to dissolve parliament ... and we re going.  the labour government officially has until june 2006 to hold general election  but in recent years governments have favoured four-year terms."]

seq = tokenizer.texts_to_sequences(txt)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)
labels = ['sport', 'bussiness', 'politics', 'tech', 'entertainment'] 

print(pred)
print(np.argmax(pred))
print(labels[np.argmax(pred)-1])
# Out:
# [[1.5735817e-04 2.6085167e-04 3.2820776e-03 9.9299192e-01 1.1172922e-03
#   2.1904306e-03]]
# 3
# politics

# %%
txt = ["call to save manufacturing jobs the trades union congress (tuc) is calling on the government to stem job losses in manufacturing firms by reviewing the help it gives companies.  the tuc said in its submission before the budget that action is needed because of 105 000 jobs lost from the sector over the last year. it calls for better pensions  child care provision and decent wages. the 36-page submission also urges the government to examine support other european countries provide to industry. tuc general secretary brendan barber called for  a commitment to policies that will make a real difference to the lives of working people.    greater investment in childcare strategies and the people delivering that childcare will increases the options available to working parents   he said.  a commitment to our public services and manufacturing sector ensures that we can continue to compete on a global level and deliver the frontline services that this country needs.  he also called for  practical measures  to help pensioners  especially women who he said  are most likely to retire in poverty . the submission also calls for decent wages and training for people working in the manufacturing sector."]

seq = tokenizer.texts_to_sequences(txt)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)
labels = ['sport', 'bussiness', 'politics', 'tech', 'entertainment'] 

print(pred)
print(np.argmax(pred))
print(labels[np.argmax(pred)-1])
# Out:
# [[1.1402832e-04 2.4513642e-03 9.7615951e-01 2.0509444e-02 9.6237731e-05
#   6.6940807e-04]]
# 2
# bussiness

# %% [markdown]
# I can see that it correctly predicted them as politics and business

# %% [markdown]
# ## Time Series Prediction
#
# ### Load dataset

# %%
import pandas
import matplotlib.pyplot as plt
dataset = pandas.read_csv('airline-passengers.csv', usecols=[1], engine='python')
plt.plot(dataset)
plt.show()

# %% [markdown]
# I can see that the number of airline passengers increases overtime and follows seasonality adjustments

# %%
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
numpy.random.seed(7)

# load the dataset
dataframe = pandas.read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# %% [markdown]
# Rescale data

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %% [markdown]
# Train-test split

# %%
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 96 48

# %% [markdown]
# Create Dataset

# %%
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %% [markdown]
# Reshape dataset

# %%
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# Create and fit LSTM network

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 94/94 - 1s - loss: 0.0576 - 1s/epoch - 11ms/step
# Epoch 2/100
# 94/94 - 0s - loss: 0.0298 - 66ms/epoch - 701us/step
# Epoch 3/100
# 94/94 - 0s - loss: 0.0220 - 64ms/epoch - 679us/step
# Epoch 4/100
# 94/94 - 0s - loss: 0.0196 - 70ms/epoch - 745us/step
# Epoch 5/100
# 94/94 - 0s - loss: 0.0186 - 70ms/epoch - 743us/step
# Epoch 6/100
# 94/94 - 0s - loss: 0.0176 - 68ms/epoch - 720us/step
# Epoch 7/100
# 94/94 - 0s - loss: 0.0167 - 66ms/epoch - 707us/step
# Epoch 8/100
# 94/94 - 0s - loss: 0.0157 - 63ms/epoch - 667us/step
# Epoch 9/100
# 94/94 - 0s - loss: 0.0149 - 65ms/epoch - 693us/step
# Epoch 10/100
# 94/94 - 0s - loss: 0.0138 - 71ms/epoch - 753us/step
# Epoch 11/100
# 94/94 - 0s - loss: 0.0130 - 70ms/epoch - 739us/step
# Epoch 12/100
# 94/94 - 0s - loss: 0.0122 - 61ms/epoch - 653us/step
# Epoch 13/100
# 94/94 - 0s - loss: 0.0111 - 68ms/epoch - 725us/step
# Epoch 14/100
# 94/94 - 0s - loss: 0.0102 - 64ms/epoch - 684us/step
# Epoch 15/100
# 94/94 - 0s - loss: 0.0093 - 64ms/epoch - 681us/step
# Epoch 16/100
# 94/94 - 0s - loss: 0.0084 - 62ms/epoch - 655us/step
# Epoch 17/100
# 94/94 - 0s - loss: 0.0076 - 72ms/epoch - 768us/step
# Epoch 18/100
# 94/94 - 0s - loss: 0.0068 - 65ms/epoch - 694us/step
# Epoch 19/100
# 94/94 - 0s - loss: 0.0060 - 62ms/epoch - 661us/step
# Epoch 20/100
# 94/94 - 0s - loss: 0.0054 - 70ms/epoch - 740us/step
# Epoch 21/100
# 94/94 - 0s - loss: 0.0047 - 66ms/epoch - 705us/step
# Epoch 22/100
# 94/94 - 0s - loss: 0.0041 - 61ms/epoch - 652us/step
# Epoch 23/100
# 94/94 - 0s - loss: 0.0037 - 64ms/epoch - 677us/step
# Epoch 24/100
# 94/94 - 0s - loss: 0.0020 - 64ms/epoch - 679us/step
# Epoch 92/100
# 94/94 - 0s - loss: 0.0020 - 64ms/epoch - 677us/step
# Epoch 93/100
# 94/94 - 0s - loss: 0.0020 - 66ms/epoch - 701us/step
# Epoch 94/100
# 94/94 - 0s - loss: 0.0020 - 66ms/epoch - 702us/step
# Epoch 95/100
# 94/94 - 0s - loss: 0.0019 - 64ms/epoch - 679us/step
# Epoch 96/100
# 94/94 - 0s - loss: 0.0021 - 64ms/epoch - 683us/step
# Epoch 97/100
# 94/94 - 0s - loss: 0.0020 - 64ms/epoch - 681us/step
# Epoch 98/100
# 94/94 - 0s - loss: 0.0020 - 65ms/epoch - 689us/step
# Epoch 99/100
# 94/94 - 0s - loss: 0.0021 - 65ms/epoch - 689us/step
# Epoch 100/100
# 94/94 - 0s - loss: 0.0020 - 68ms/epoch - 721us/step

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 22.97 RMSE
# Test Score: 48.76 RMSE

# %% [markdown]
# I can see that the train data is slightly overfit since the RMSE is a 23 while the test RMSE is 49

# %% [markdown]
# Shifting test and train predictions to match the original way the dataset was prepared

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# #### Repeating same code but make a bigger window width

# %%
# LSTM for international airline passengers problem with window regression framing
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# LSTM for international airline passengers problem with window regression framing
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Epoch 1/100
# 92/92 - 1s - loss: 0.0174 - 978ms/epoch - 11ms/step
# Epoch 2/100
# 92/92 - 0s - loss: 0.0073 - 62ms/epoch - 669us/step
# Epoch 3/100
# 92/92 - 0s - loss: 0.0059 - 62ms/epoch - 670us/step
# Epoch 4/100
# 92/92 - 0s - loss: 0.0054 - 62ms/epoch - 672us/step
# Epoch 5/100
# 92/92 - 0s - loss: 0.0048 - 62ms/epoch - 678us/step
# Epoch 6/100
# 92/92 - 0s - loss: 0.0043 - 64ms/epoch - 691us/step
# Epoch 7/100
# 92/92 - 0s - loss: 0.0040 - 64ms/epoch - 698us/step
# Epoch 8/100
# 92/92 - 0s - loss: 0.0038 - 62ms/epoch - 671us/step
# Epoch 9/100
# 92/92 - 0s - loss: 0.0036 - 62ms/epoch - 673us/step
# Epoch 10/100
# 92/92 - 0s - loss: 0.0035 - 62ms/epoch - 675us/step
# Epoch 11/100
# 92/92 - 0s - loss: 0.0034 - 62ms/epoch - 676us/step
# Epoch 12/100
# 92/92 - 0s - loss: 0.0033 - 62ms/epoch - 671us/step
# Epoch 13/100
# 92/92 - 0s - loss: 0.0033 - 63ms/epoch - 687us/step
# Epoch 14/100
# 92/92 - 0s - loss: 0.0032 - 63ms/epoch - 685us/step
# Epoch 15/100
# 92/92 - 0s - loss: 0.0033 - 62ms/epoch - 671us/step
# Epoch 16/100
# 92/92 - 0s - loss: 0.0031 - 68ms/epoch - 743us/step
# Epoch 17/100
# 92/92 - 0s - loss: 0.0031 - 189ms/epoch - 2ms/step
# Epoch 18/100
# 92/92 - 0s - loss: 0.0031 - 63ms/epoch - 688us/step
# Epoch 19/100
# 92/92 - 0s - loss: 0.0031 - 60ms/epoch - 654us/step
# Epoch 20/100
# 92/92 - 0s - loss: 0.0030 - 68ms/epoch - 735us/step
# Epoch 21/100
# Epoch 88/100
# 92/92 - 0s - loss: 0.0018 - 60ms/epoch - 651us/step
# Epoch 89/100
# 92/92 - 0s - loss: 0.0019 - 63ms/epoch - 685us/step
# Epoch 90/100
# 92/92 - 0s - loss: 0.0019 - 62ms/epoch - 671us/step
# Epoch 91/100
# 92/92 - 0s - loss: 0.0018 - 60ms/epoch - 656us/step
# Epoch 92/100
# 92/92 - 0s - loss: 0.0019 - 61ms/epoch - 666us/step
# Epoch 93/100
# 92/92 - 0s - loss: 0.0018 - 68ms/epoch - 741us/step
# Epoch 94/100
# 92/92 - 0s - loss: 0.0019 - 65ms/epoch - 709us/step
# Epoch 95/100
# 92/92 - 0s - loss: 0.0018 - 60ms/epoch - 653us/step
# Epoch 96/100
# 92/92 - 0s - loss: 0.0019 - 59ms/epoch - 640us/step
# Epoch 97/100
# 92/92 - 0s - loss: 0.0018 - 62ms/epoch - 673us/step
# Epoch 98/100
# 92/92 - 0s - loss: 0.0019 - 65ms/epoch - 707us/step
# Epoch 99/100
# 92/92 - 0s - loss: 0.0017 - 60ms/epoch - 652us/step
# Epoch 100/100
# 92/92 - 0s - loss: 0.0018 - 62ms/epoch - 676us/step
# Train Score: 21.44 RMSE
# Test Score: 60.58 RMSE
# Epoch 1/100
# 92/92 - 1s - loss: 0.0265 - 915ms/epoch - 10ms/step
# Epoch 2/100
# 92/92 - 0s - loss: 0.0100 - 68ms/epoch - 742us/step
# Epoch 3/100
# 92/92 - 0s - loss: 0.0076 - 65ms/epoch - 704us/step
# Epoch 4/100
# 92/92 - 0s - loss: 0.0067 - 62ms/epoch - 676us/step
# Epoch 5/100
# 92/92 - 0s - loss: 0.0062 - 61ms/epoch - 668us/step
# Epoch 6/100
# 92/92 - 0s - loss: 0.0054 - 64ms/epoch - 700us/step
# Epoch 7/100
# 92/92 - 0s - loss: 0.0050 - 63ms/epoch - 680us/step
# Epoch 8/100
# 92/92 - 0s - loss: 0.0047 - 61ms/epoch - 667us/step
# Epoch 9/100
# 92/92 - 0s - loss: 0.0044 - 63ms/epoch - 680us/step
# Epoch 10/100
# 92/92 - 0s - loss: 0.0041 - 72ms/epoch - 781us/step
# Epoch 11/100
# 92/92 - 0s - loss: 0.0041 - 61ms/epoch - 666us/step
# Epoch 12/100
# 92/92 - 0s - loss: 0.0039 - 62ms/epoch - 670us/step
# Epoch 13/100
# 92/92 - 0s - loss: 0.0039 - 61ms/epoch - 664us/step
# Epoch 14/100
# 92/92 - 0s - loss: 0.0038 - 63ms/epoch - 684us/step
# Epoch 15/100
# 92/92 - 0s - loss: 0.0038 - 67ms/epoch - 731us/step
# Epoch 16/100
# 92/92 - 0s - loss: 0.0037 - 63ms/epoch - 685us/step
# Epoch 17/100
# 92/92 - 0s - loss: 0.0037 - 62ms/epoch - 671us/step
# Epoch 18/100
# 92/92 - 0s - loss: 0.0036 - 65ms/epoch - 711us/step
# Epoch 19/100
# 92/92 - 0s - loss: 0.0037 - 62ms/epoch - 673us/step
# Epoch 20/100
# 92/92 - 0s - loss: 0.0035 - 64ms/epoch - 696us/step
# Epoch 21/100
# 92/92 - 0s - loss: 0.0036 - 62ms/epoch - 675us/step
# Epoch 22/100
# 92/92 - 0s - loss: 0.0036 - 62ms/epoch - 671us/step
# Epoch 23/100
# 92/92 - 0s - loss: 0.0034 - 63ms/epoch - 689us/step
# Epoch 24/100
# 92/92 - 0s - loss: 0.0034 - 62ms/epoch - 671us/step
# Epoch 25/100
# 92/92 - 0s - loss: 0.0034 - 66ms/epoch - 712us/step
# Epoch 26/100
# 92/92 - 0s - loss: 0.0034 - 72ms/epoch - 778us/step
# Epoch 27/100
# 92/92 - 0s - loss: 0.0033 - 62ms/epoch - 673us/step
# Epoch 28/100
# 92/92 - 0s - loss: 0.0034 - 63ms/epoch - 686us/step
# Epoch 29/100
# 92/92 - 0s - loss: 0.0033 - 61ms/epoch - 666us/step
# Epoch 30/100
# 92/92 - 0s - loss: 0.0033 - 70ms/epoch - 757us/step
# Epoch 31/100
# 92/92 - 0s - loss: 0.0032 - 63ms/epoch - 684us/step
# Epoch 32/100
# 92/92 - 0s - loss: 0.0032 - 64ms/epoch - 696us/step
# Epoch 33/100
# 92/92 - 0s - loss: 0.0032 - 63ms/epoch - 685us/step
# Epoch 34/100
# 92/92 - 0s - loss: 0.0031 - 65ms/epoch - 705us/step
# Epoch 35/100
# 92/92 - 0s - loss: 0.0032 - 66ms/epoch - 717us/step
# Epoch 36/100
# 92/92 - 0s - loss: 0.0032 - 62ms/epoch - 674us/step
# Epoch 37/100
# 92/92 - 0s - loss: 0.0032 - 64ms/epoch - 696us/step
# Epoch 38/100
# 92/92 - 0s - loss: 0.0030 - 63ms/epoch - 686us/step
# Epoch 39/100
# 92/92 - 0s - loss: 0.0031 - 62ms/epoch - 674us/step
# Epoch 40/100
# 92/92 - 0s - loss: 0.0030 - 67ms/epoch - 728us/step
# Epoch 41/100
# 92/92 - 0s - loss: 0.0031 - 63ms/epoch - 685us/step
# Epoch 42/100
# 92/92 - 0s - loss: 0.0030 - 66ms/epoch - 717us/step
# Epoch 43/100
# 92/92 - 0s - loss: 0.0029 - 64ms/epoch - 696us/step
# Epoch 44/100
# 92/92 - 0s - loss: 0.0029 - 62ms/epoch - 674us/step
# Epoch 45/100
# 92/92 - 0s - loss: 0.0028 - 63ms/epoch - 685us/step
# Epoch 46/100
# 92/92 - 0s - loss: 0.0029 - 63ms/epoch - 685us/step
# Epoch 47/100
# 92/92 - 0s - loss: 0.0029 - 66ms/epoch - 717us/step
# Epoch 48/100
# 92/92 - 0s - loss: 0.0028 - 64ms/epoch - 696us/step
# Epoch 49/100
# 92/92 - 0s - loss: 0.0029 - 63ms/epoch - 685us/step
# Epoch 50/100
# 92/92 - 0s - loss: 0.0028 - 67ms/epoch - 728us/step
# Epoch 51/100
# 92/92 - 0s - loss: 0.0028 - 63ms/epoch - 685us/step
# Epoch 52/100
# 92/92 - 0s - loss: 0.0027 - 63ms/epoch - 685us/step
# Epoch 53/100
# 92/92 - 0s - loss: 0.0027 - 64ms/epoch - 696us/step
# Epoch 54/100
# 92/92 - 0s - loss: 0.0027 - 61ms/epoch - 663us/step
# Epoch 55/100
# 92/92 - 0s - loss: 0.0027 - 62ms/epoch - 673us/step
# Epoch 56/100
# 92/92 - 0s - loss: 0.0027 - 70ms/epoch - 761us/step
# Epoch 57/100
# 92/92 - 0s - loss: 0.0027 - 63ms/epoch - 685us/step
# Epoch 58/100
# 92/92 - 0s - loss: 0.0026 - 64ms/epoch - 696us/step
# Epoch 59/100
# 92/92 - 0s - loss: 0.0026 - 62ms/epoch - 674us/step
# Epoch 60/100
# 92/92 - 0s - loss: 0.0026 - 63ms/epoch - 685us/step
# Epoch 61/100
# 92/92 - 0s - loss: 0.0026 - 64ms/epoch - 694us/step
# Epoch 62/100
# 92/92 - 0s - loss: 0.0025 - 63ms/epoch - 680us/step
# Epoch 63/100
# 92/92 - 0s - loss: 0.0025 - 64ms/epoch - 696us/step
# Epoch 64/100
# 92/92 - 0s - loss: 0.0025 - 65ms/epoch - 707us/step
# Epoch 65/100
# 92/92 - 0s - loss: 0.0025 - 68ms/epoch - 734us/step
# Epoch 66/100
# 92/92 - 0s - loss: 0.0025 - 63ms/epoch - 685us/step
# Epoch 67/100
# 92/92 - 0s - loss: 0.0025 - 63ms/epoch - 685us/step
# Epoch 68/100
# 92/92 - 0s - loss: 0.0024 - 64ms/epoch - 696us/step
# Epoch 69/100
# 92/92 - 0s - loss: 0.0024 - 63ms/epoch - 685us/step
# Epoch 70/100
# 92/92 - 0s - loss: 0.0024 - 62ms/epoch - 674us/step
# Epoch 71/100
# 92/92 - 0s - loss: 0.0024 - 61ms/epoch - 663us/step
# Epoch 72/100
# 92/92 - 0s - loss: 0.0024 - 69ms/epoch - 750us/step
# Epoch 73/100
# 92/92 - 0s - loss: 0.0024 - 63ms/epoch - 682us/step
# Epoch 74/100
# 92/92 - 0s - loss: 0.0023 - 63ms/epoch - 686us/step
# Epoch 75/100
# 92/92 - 0s - loss: 0.0024 - 61ms/epoch - 665us/step
# Epoch 76/100
# 92/92 - 0s - loss: 0.0023 - 63ms/epoch - 683us/step
# Epoch 77/100
# 92/92 - 0s - loss: 0.0023 - 64ms/epoch - 698us/step
# Epoch 78/100
# 92/92 - 0s - loss: 0.0024 - 63ms/epoch - 688us/step
# Epoch 79/100
# 92/92 - 0s - loss: 0.0024 - 62ms/epoch - 670us/step
# Epoch 80/100
# 92/92 - 0s - loss: 0.0023 - 61ms/epoch - 663us/step
# Epoch 81/100
# 92/92 - 0s - loss: 0.0023 - 69ms/epoch - 749us/step
# Epoch 82/100
# 92/92 - 0s - loss: 0.0022 - 61ms/epoch - 661us/step
# Epoch 83/100
# 92/92 - 0s - loss: 0.0023 - 64ms/epoch - 698us/step
# Epoch 84/100
# 92/92 - 0s - loss: 0.0022 - 63ms/epoch - 687us/step
# Epoch 85/100
# 92/92 - 0s - loss: 0.0022 - 65ms/epoch - 701us/step
# Epoch 86/100
# 92/92 - 0s - loss: 0.0022 - 63ms/epoch - 685us/step
# Epoch 87/100
# 92/92 - 0s - loss: 0.0022 - 61ms/epoch - 664us/step
# Epoch 88/100
# 92/92 - 0s - loss: 0.0022 - 64ms/epoch - 692us/step
# Epoch 89/100
# 92/92 - 0s - loss: 0.0022 - 62ms/epoch - 674us/step
# Epoch 90/100
# 92/92 - 0s - loss: 0.0021 - 71ms/epoch - 766us/step
# Epoch 91/100
# 92/92 - 0s - loss: 0.0022 - 61ms/epoch - 663us/step
# Epoch 92/100
# 92/92 - 0s - loss: 0.0021 - 63ms/epoch - 682us/step
# Epoch 93/100
# 92/92 - 0s - loss: 0.0021 - 63ms/epoch - 681us/step
# Epoch 94/100
# 92/92 - 0s - loss: 0.0021 - 64ms/epoch - 696us/step
# Epoch 95/100
# 92/92 - 0s - loss: 0.0021 - 63ms/epoch - 687us/step
# Epoch 96/100
# 92/92 - 0s - loss: 0.0021 - 64ms/epoch - 694us/step
# Epoch 97/100
# 92/92 - 0s - loss: 0.0021 - 63ms/epoch - 685us/step
# Epoch 98/100
# 92/92 - 0s - loss: 0.0021 - 64ms/epoch - 695us/step
# Epoch 99/100
# 92/92 - 0s - loss: 0.0021 - 66ms/epoch - 718us/step
# Epoch 100/100
# 92/92 - 0s - loss: 0.0020 - 64ms/epoch - 695us/step
# Train Score: 23.09 RMSE
# Test Score: 57.84 RMSE

# %% [markdown]
# #### LSTM for Regression with Time Steps

# %%
# LSTM for international airline passengers problem with time step regression framing
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], 1))
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Epoch 1/100
# 92/92 - 1s - loss: 0.0332 - 932ms/epoch - 10ms/step
# Epoch 2/100
# 92/92 - 0s - loss: 0.0122 - 83ms/epoch - 903us/step
# Epoch 3/100
# 92/92 - 0s - loss: 0.0103 - 76ms/epoch - 830us/step
# Epoch 4/100
# 92/92 - 0s - loss: 0.0088 - 78ms/epoch - 848us/step
# Epoch 5/100
# 92/92 - 0s - loss: 0.0075 - 78ms/epoch - 843us/step
# Epoch 6/100
# 92/92 - 0s - loss: 0.0066 - 76ms/epoch - 821us/step
# Epoch 7/100
# 92/92 - 0s - loss: 0.0057 - 79ms/epoch - 861us/step
# Epoch 8/100
# 92/92 - 0s - loss: 0.0052 - 77ms/epoch - 840us/step
# Epoch 9/100
# 92/92 - 0s - loss: 0.0047 - 84ms/epoch - 917us/step
# Epoch 10/100
# 92/92 - 0s - loss: 0.0047 - 81ms/epoch - 882us/step
# Epoch 11/100
# 92/92 - 0s - loss: 0.0043 - 78ms/epoch - 850us/step
# Epoch 12/100
# 92/92 - 0s - loss: 0.0042 - 78ms/epoch - 843us/step
# Epoch 13/100
# 92/92 - 0s - loss: 0.0040 - 81ms/epoch - 880us/step
# Epoch 14/100
# 92/92 - 0s - loss: 0.0041 - 78ms/epoch - 846us/step
# Epoch 15/100
# 92/92 - 0s - loss: 0.0040 - 78ms/epoch - 849us/step
# Epoch 16/100
# 92/92 - 0s - loss: 0.0040 - 76ms/epoch - 826us/step
# Epoch 17/100
# 92/92 - 0s - loss: 0.0040 - 79ms/epoch - 858us/step
# Epoch 18/100
# 92/92 - 0s - loss: 0.0040 - 77ms/epoch - 842us/step
# Epoch 19/100
# 92/92 - 0s - loss: 0.0039 - 80ms/epoch - 870us/step
# Epoch 20/100
# 92/92 - 0s - loss: 0.0039 - 78ms/epoch - 844us/step
# Epoch 21/100
# 92/92 - 0s - loss: 0.0039 - 80ms/epoch - 872us/step
# Epoch 22/100
# 92/92 - 0s - loss: 0.0038 - 86ms/epoch - 929us/step
# Epoch 23/100
# 92/92 - 0s - loss: 0.0039 - 79ms/epoch - 860us/step
# Epoch 24/100
# 92/92 - 0s - loss: 0.0038 - 78ms/epoch - 845us/step
# Epoch 92/100
# 92/92 - 0s - loss: 0.0017 - 80ms/epoch - 865us/step
# Epoch 93/100
# 92/92 - 0s - loss: 0.0017 - 77ms/epoch - 834us/step
# Epoch 94/100
# 92/92 - 0s - loss: 0.0017 - 83ms/epoch - 903us/step
# Epoch 95/100
# 92/92 - 0s - loss: 0.0019 - 77ms/epoch - 832us/step
# Epoch 96/100
# 92/92 - 0s - loss: 0.0017 - 78ms/epoch - 850us/step
# Epoch 97/100
# 92/92 - 0s - loss: 0.0017 - 82ms/epoch - 894us/step
# Epoch 98/100
# 92/92 - 0s - loss: 0.0017 - 81ms/epoch - 875us/step
# Epoch 99/100
# 92/92 - 0s - loss: 0.0017 - 76ms/epoch - 828us/step
# Epoch 100/100
# 92/92 - 0s - loss: 0.0017 - 78ms/epoch - 848us/step
# Train Score: 20.94 RMSE
# Test Score: 50.16 RMSE

# %% [markdown]
# The Train and test accuracy actually got a little bit better with time steps instead of phasing out prior inputs.

# %% [markdown]
# #### LSTM with memory between batches

# %%
# LSTM for international airline passengers problem with memory
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], 1))
# create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
for i in range(100):
	model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
	model.reset_states()
# make predictions
trainPredict = model.predict(trainX, batch_size=batch_size)
model.reset_states()
testPredict = model.predict(testX, batch_size=batch_size)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 92/92 - 1s - loss: 0.0087 - 972ms/epoch - 11ms/step
# 92/92 - 0s - loss: 0.0169 - 81ms/epoch - 883us/step
# 92/92 - 0s - loss: 0.0100 - 85ms/epoch - 925us/step
# 92/92 - 0s - loss: 0.0068 - 79ms/epoch - 862us/step
# 92/92 - 0s - loss: 0.0056 - 80ms/epoch - 870us/step
# 92/92 - 0s - loss: 0.0052 - 78ms/epoch - 847us/step
# 92/92 - 0s - loss: 0.0051 - 82ms/epoch - 895us/step
# 92/92 - 0s - loss: 0.0050 - 83ms/epoch - 902us/step
# 92/92 - 0s - loss: 0.0049 - 84ms/epoch - 916us/step
# 92/92 - 0s - loss: 0.0049 - 87ms/epoch - 946us/step
# 92/92 - 0s - loss: 0.0049 - 83ms/epoch - 906us/step
# 92/92 - 0s - loss: 0.0048 - 84ms/epoch - 910us/step
# 92/92 - 0s - loss: 0.0048 - 84ms/epoch - 908us/step
# 92/92 - 0s - loss: 0.0048 - 86ms/epoch - 940us/step
# 92/92 - 0s - loss: 0.0047 - 89ms/epoch - 963us/step
# 92/92 - 0s - loss: 0.0047 - 80ms/epoch - 872us/step
# 92/92 - 0s - loss: 0.0047 - 88ms/epoch - 952us/step
# 92/92 - 0s - loss: 0.0047 - 79ms/epoch - 855us/step
# 92/92 - 0s - loss: 0.0046 - 82ms/epoch - 891us/step
# 92/92 - 0s - loss: 0.0046 - 85ms/epoch - 923us/step
# 92/92 - 0s - loss: 0.0046 - 84ms/epoch - 913us/step
# 92/92 - 0s - loss: 0.0045 - 87ms/epoch - 944us/step
# 92/92 - 0s - loss: 0.0045 - 81ms/epoch - 880us/step
# 92/92 - 0s - loss: 0.0045 - 84ms/epoch - 913us/step
# 92/92 - 0s - loss: 0.0045 - 88ms/epoch - 951us/step
# 92/92 - 0s - loss: 0.0045 - 78ms/epoch - 847us/step
# 92/92 - 0s - loss: 0.0044 - 79ms/epoch - 857us/step
# 92/92 - 0s - loss: 0.0044 - 81ms/epoch - 880us/step
# 92/92 - 0s - loss: 0.0044 - 84ms/epoch - 910us/step
# 92/92 - 0s - loss: 0.0044 - 86ms/epoch - 937us/step
# 92/92 - 0s - loss: 0.0044 - 83ms/epoch - 901us/step
# 92/92 - 0s - loss: 0.0043 - 79ms/epoch - 855us/step
# 92/92 - 0s - loss: 0.0043 - 81ms/epoch - 885us/step
# 92/92 - 0s - loss: 0.0036 - 80ms/epoch - 865us/step
# 92/92 - 0s - loss: 0.0036 - 85ms/epoch - 921us/step
# 92/92 - 0s - loss: 0.0036 - 84ms/epoch - 911us/step
# 92/92 - 0s - loss: 0.0036 - 79ms/epoch - 858us/step
# 92/92 - 0s - loss: 0.0036 - 79ms/epoch - 856us/step
# 92/92 - 0s - loss: 0.0035 - 80ms/epoch - 872us/step
# 92/92 - 0s - loss: 0.0035 - 83ms/epoch - 903us/step
# 92/92 - 0s - loss: 0.0035 - 87ms/epoch - 941us/step
# 92/92 - 0s - loss: 0.0035 - 84ms/epoch - 910us/step
# 92/92 - 0s - loss: 0.0035 - 84ms/epoch - 911us/step
# 92/92 - 0s - loss: 0.0034 - 85ms/epoch - 924us/step
# 92/92 - 0s - loss: 0.0034 - 85ms/epoch - 928us/step
# 92/92 - 0s - loss: 0.0034 - 78ms/epoch - 852us/step
# 92/92 - 0s - loss: 0.0034 - 83ms/epoch - 903us/step
# 92/92 - 0s - loss: 0.0033 - 79ms/epoch - 859us/step
# 92/92 - 0s - loss: 0.0033 - 82ms/epoch - 890us/step
# 92/92 - 0s - loss: 0.0033 - 85ms/epoch - 922us/step
# 92/92 - 0s - loss: 0.0033 - 85ms/epoch - 926us/step
# 92/92 - 0s - loss: 0.0033 - 79ms/epoch - 863us/step
# 92/92 - 0s - loss: 0.0032 - 83ms/epoch - 907us/step
# 92/92 - 0s - loss: 0.0032 - 80ms/epoch - 867us/step
# 92/92 - 0s - loss: 0.0032 - 82ms/epoch - 895us/step
# 92/92 - 0s - loss: 0.0032 - 80ms/epoch - 875us/step
# 92/92 - 0s - loss: 0.0031 - 79ms/epoch - 862us/step
# Train Score: 28.73 RMSE
# Test Score: 80.67 RMSE

# %% [markdown]
# The Test score with this is worse than it was in the original method

# %% [markdown]
# #### Stacked LSTMs with memory between bacthes

# %%
# Stacked LSTM for international airline passengers problem with memory
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], 1))
# create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
for i in range(100):
	model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
	model.reset_states()
# make predictions
trainPredict = model.predict(trainX, batch_size=batch_size)
model.reset_states()
testPredict = model.predict(testX, batch_size=batch_size)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 92/92 - 2s - loss: 0.0050 - 2s/epoch - 18ms/step
# 92/92 - 0s - loss: 0.0218 - 126ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0134 - 126ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0091 - 127ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0069 - 127ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0060 - 127ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0057 - 124ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0055 - 134ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0055 - 125ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0054 - 135ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0054 - 126ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0054 - 125ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0053 - 124ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0053 - 133ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0053 - 124ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0053 - 130ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0053 - 125ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0053 - 128ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0053 - 123ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0044 - 130ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0043 - 126ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0043 - 127ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0042 - 132ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0042 - 128ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0041 - 132ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0041 - 130ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0040 - 126ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0040 - 125ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0039 - 126ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0039 - 123ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0039 - 132ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0038 - 123ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0038 - 124ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0037 - 126ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0037 - 127ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0036 - 124ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0036 - 129ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0035 - 124ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0036 - 126ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0036 - 126ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0036 - 127ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0035 - 123ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0034 - 128ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0032 - 138ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0031 - 122ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0030 - 124ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0028 - 125ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0030 - 125ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0039 - 127ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0042 - 123ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0043 - 131ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0083 - 122ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0036 - 132ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0032 - 124ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0028 - 127ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0026 - 127ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0025 - 130ms/epoch - 1ms/step
# 92/92 - 0s - loss: 0.0024 - 125ms/epoch - 1ms/step
# Train Score: 27.92 RMSE
# Test Score: 125.62 RMSE

# %% [markdown]
# The test score is worse than it was in the original example showing that more memory in stacked LSTMS doesn't always work
